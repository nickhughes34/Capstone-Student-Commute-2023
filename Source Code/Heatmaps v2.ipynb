# %%
# !pip install gmaps

# %%
import gmaps
import gmaps.datasets
import pandas as pd

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7dc5f8f7-ad0a-41d4-a501-f195bbaf9433" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7dc5f8f7-ad0a-41d4-a501-f195bbaf9433">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
coords = pd.read_excel("winter_coords.xlsx", usecols=["latitude", "longitude"])
display(coords.head())
# Out:
#     latitude  longitude
# 0  43.659176 -79.736895
# 1  44.346618 -78.311875
# 2  43.942967 -78.860630
# 3  44.157285 -79.863518
# 4  43.949462 -78.894086

# %%
gmaps.configure(api_key='CHANGE TO YOUR KEY') 
figure_layout = {
    'width': '1000px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px'
}

DRegion_coordinates = (43.945051, -78.893573)
OnTech_coordinates = [(43.9456, -78.8968)]
locations = coords[['latitude', 'longitude']]
fig = gmaps.figure(center=DRegion_coordinates, zoom_level=12, layout=figure_layout)
marker = gmaps.marker_layer(OnTech_coordinates, label='A')
fig.add_layer(marker)
fig.add_layer(gmaps.heatmap_layer(locations, max_intensity=100, point_radius=20))

#symbols = gmaps.symbol_layer((43.945051, -78.893573), fill_color='red', stroke_color='red')
#fig.add_layer(symbols)

display(fig)
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='1px', width='1000px'))

# %%
gmaps.configure(api_key='CHANGE TO YOUR KEY') 
figure_layout = {
    'width': '1000px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px'
}

#L1K, L1T, L1G, L1R, L1Z, L1N, L1V, M1B, L3S, L1S
top_coordinates = [
    (43.9456, -78.8968), (43.9332, -78.8439), 
    (43.8776, -79.0476), (43.9260, -78.8666), 
    (43.9232, -78.9345), (43.8732, -79.0023),
    (43.8697, -78.9175), (43.8275, -79.1153), 
    (43.8067, -79.1944),  (43.8509, -79.2620), 
    (43.8429, -79.0306)]
DRegion_coordinates = (43.945051, -78.893573)

fig = gmaps.figure(center=DRegion_coordinates, zoom_level=12, layout=figure_layout)
marker = gmaps.marker_layer(top_coordinates)
marker.markers[0].label = 'A'
marker.markers[1].label = '1'
marker.markers[2].label = '2'
marker.markers[3].label = '3'
marker.markers[4].label = '4'
marker.markers[5].label = '5'
marker.markers[6].label = '6'
marker.markers[7].label = '7'
marker.markers[8].label = '8'
marker.markers[9].label = '9'
marker.markers[10].label = '10'
fig.add_layer(marker)

display(fig)
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='1px', width='1000px'))
